# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Login_bg

# %%
img=cv2.imread('Login.png')
#img.shape #(1536,2304,3)
# resize
resize_img=cv2.resize(img,(1350,750),interpolation=cv2.INTER_AREA)
plt.imshow(resize_img)
# 存檔
cv2.imwrite('Login_bg.png', resize_img)
# Out:
# True
